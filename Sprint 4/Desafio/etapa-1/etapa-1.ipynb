# %% [markdown]
# Instalando o boto3

# %%
# !pip install boto3
# Out:
# Requirement already satisfied: boto3 in c:\users\isabe\anaconda\lib\site-packages (1.36.16)
# Collecting botocore<1.37.0,>=1.36.16 (from boto3)
#   Using cached botocore-1.36.16-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\isabe\anaconda\lib\site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in c:\users\isabe\anaconda\lib\site-packages (from boto3) (0.11.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\isabe\appdata\roaming\python\python312\site-packages (from botocore<1.37.0,>=1.36.16->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\isabe\anaconda\lib\site-packages (from botocore<1.37.0,>=1.36.16->boto3) (2.2.3)
# Requirement already satisfied: six>=1.5 in c:\users\isabe\appdata\roaming\python\python312\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.37.0,>=1.36.16->boto3) (1.17.0)
# Using cached botocore-1.36.16-py3-none-any.whl (13.3 MB)
# Installing collected packages: botocore
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.34.69
#     Uninstalling botocore-1.34.69:
#       Successfully uninstalled botocore-1.34.69
# Successfully installed botocore-1.36.16
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 2.12.3 requires botocore<1.34.70,>=1.34.41, but you have botocore 1.36.16 which is incompatible.

# %% [markdown]
# Importando o Pandas

# %%
import pandas as pd

# %% [markdown]
# Leitura CSV

# %%
df = pd.read_csv('dados_cronicas_ses_2023.csv', sep=';')
df
# Out:
#          dt_obito dt_nascimento  nu_idade    sg_sexo tp_raca_cor  \
# 0      01/01/2023    30/07/1964      58.0  Masculino      Branca
# 1      01/01/2023    24/03/1992      30.0  Masculino      Branca
# 2      01/01/2023    16/04/1964      58.0  Masculino      Branca
# 3      01/01/2023    25/10/1956      66.0   Feminino      Branca
# 4      01/01/2023    19/11/1935      87.0   Feminino      Branca
# ...           ...           ...       ...        ...         ...
# 79890  31/12/2023    21/10/1942      81.0   Feminino      Branca
# 79891  31/12/2023    04/01/1938      85.0  Masculino      Branca
# 79892  31/12/2023    08/06/1924      99.0   Feminino      Branca
# 79893  31/12/2023    16/03/1953      70.0  Masculino      Branca
# 79894  31/12/2023    28/02/1963      60.0  Masculino      Branca
#
#       tp_escolaridade co_municipio_ibge_residencia  \
# 0      de 8 a 11 anos                  Divinópolis
# 1                 NaN                      Timóteo
# 2      de 8 a 11 anos                    Seritinga
# 3       de 4 a 7 anos         Governador Valadares
# 4       de 1 a 3 anos               Pedro Leopoldo
# ...               ...                          ...
# 79890        Ignorado           Carmo do Rio Claro
# 79891  de 8 a 11 anos               Belo Horizonte
# 79892         Nenhuma                      Ataléia
# 79893         Nenhuma                      Corinto
# 79894        Ignorado           Carmo do Paranaíba
#
#       co_municipio_ibge_ocorrencia co_cid_causa_basica  \
# 0                      Divinópolis                 C01
# 1                         Ipatinga                C152
# 2                         Aiuruoca                C159
# 3             Governador Valadares                C159
# 4                   Pedro Leopoldo                C169
# ...                            ...                 ...
# 79890           Carmo do Rio Claro                J841
# 79891               Belo Horizonte                J849
# 79892                      Ataléia                J969
# 79893                      Corinto                J969
# 79894           Carmo do Paranaíba                J969
#
#                          desc_cid_causa_basica  \
# 0                NEOPL MALIG DA BASE DA LINGUA
# 1                  PORCAO ABDOMINAL DO ESOFAGO
# 2                                   ESOFAGO NE
# 3                                   ESOFAGO NE
# 4                                  ESTOMAGO NE
# ...                                        ...
# 79890  OUTR DOENC PULM INTERSTICIAIS C/FIBROSE
# 79891           DOENC PULMONAR INTERSTICIAL NE
# 79892                        INSUF RESPIRAT NE
# 79893                        INSUF RESPIRAT NE
# 79894                        INSUF RESPIRAT NE
#
#                  capitulo_cid_causa_basica  \
# 0                 II. NEOPLASIAS (TUMORES)
# 1                 II. NEOPLASIAS (TUMORES)
# 2                 II. NEOPLASIAS (TUMORES)
# 3                 II. NEOPLASIAS (TUMORES)
# 4                 II. NEOPLASIAS (TUMORES)
# ...                                    ...
# 79890  X. DOENÇAS DO APARELHO RESPIRATÓRIO
# 79891  X. DOENÇAS DO APARELHO RESPIRATÓRIO
# 79892  X. DOENÇAS DO APARELHO RESPIRATÓRIO
# 79893  X. DOENÇAS DO APARELHO RESPIRATÓRIO
# 79894  X. DOENÇAS DO APARELHO RESPIRATÓRIO
#
#                 categoria_cid_causa_basica
# 0            NEOPL MALIG DA BASE DA LINGUA
# 1                   NEOPL MALIG DO ESOFAGO
# 2                   NEOPL MALIG DO ESOFAGO
# 3                   NEOPL MALIG DO ESOFAGO
# 4                  NEOPL MALIG DO ESTOMAGO
# ...                                    ...
# 79890  OUTR DOENC PULMONARES INTERSTICIAIS
# 79891  OUTR DOENC PULMONARES INTERSTICIAIS
# 79892                  INSUF RESPIRAT NCOP
# 79893                  INSUF RESPIRAT NCOP
# 79894                  INSUF RESPIRAT NCOP
#
# [79895 rows x 12 columns]

# %% [markdown]
# Visualizei na extensão do "VS Code" chamado "Data Wrangler" o dataframe criado, e percebi que as linhas do dataframe estavam bem formatadas, então não precisei tratar os dados do arquivo CSV.

# %% [markdown]
# Importando o Boto3 e o StringIO e fazendo upload do CSV para a AWS

# %%
import boto3
from io import StringIO


session = boto3.Session(profile_name="daniel.schulz")
s3 = session.client("s3")


bucket_name = "daniel.schulz"


s3.create_bucket(
    Bucket=bucket_name

)
print(f"Bucket {bucket_name} criado com sucesso!")


csv_buffer = StringIO()
df.to_csv(csv_buffer, index=False)


s3.put_object(Bucket=bucket_name, Key="dados_cronicas_obitos.csv", Body=csv_buffer.getvalue())

print(f"Arquivo CSV enviado para o bucket {bucket_name}")
# Out:
# Bucket daniel.schulz criado com sucesso!
# Arquivo CSV enviado para o bucket daniel.schulz
